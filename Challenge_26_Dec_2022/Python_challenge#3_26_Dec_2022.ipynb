# %% [markdown]
# ### Print following pattern(with digita) for any given number 'n'.
# 1. Ask user number of rows
# Follow the examples below for to print these patterns

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Hint
#
# ![image-2.png](attachment:image-2.png)

# %%
n = 5
for row in range(1,n+1):
    for col in range(1,n+1):
        print(col, end='')
# Out:
# 1234512345123451234512345
